# %% [markdown]
# # `gymnax`: Classic Gym Environments in JAX
# ### [Last Update: June 2022][![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RobertTLange/gymnax/blob/main/examples/getting_started.ipynb)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
mpl.rcParams['figure.dpi']= 300

import sys
sys.path.append("..")
from utils.helpers import load_pkl_object

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_style("whitegrid")
sns.set_context("poster")
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
env_names = ['Acrobot-v1', 'Pendulum-v1', 'CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0',
             # 'Seaquest-MinAtar',
             'Asterix-MinAtar', 'Breakout-MinAtar', 'Freeway-MinAtar',  'SpaceInvaders-MinAtar'
             ]

fig, axs = plt.subplots(figsize=(20, 12), nrows=3, ncols=3)

for i, e in enumerate(env_names):
    ax = axs.flatten()[i]
    
    results = load_pkl_object(f"../agents/{e}/ppo.pkl")
    steps = results["log_steps"]
    cum_rew = results["log_return"]
    ax.plot(steps, cum_rew, label="PPO - lr: 5e-04")

    results = load_pkl_object(f"../agents/{e}/ppo0.001.pkl")
    steps = results["log_steps"]
    cum_rew = results["log_return"]
    ax.plot(steps, cum_rew, label="PPO - lr: 1e-03")

    results = load_pkl_object(f"../agents/{e}/ppo0.0001.pkl")
    steps = results["log_steps"]
    cum_rew = results["log_return"]
    ax.plot(steps, cum_rew, label="PPO - lr: 1e-04")

    ax.set_xticks(steps)
    ax.xaxis.set_major_locator(plt.MaxNLocator(4))
    ax.yaxis.set_major_locator(plt.MaxNLocator(4))
    
    if i in [6, 7, 8]:
        ax.set_xlabel('Env Steps')
    if i in [0, 3, 6]:
        ax.set_ylabel('Return')
    ax.set_title(f'{e}')
    if i == 8:
        ax.legend(fontsize=16)
    print(e, cum_rew[-1])

fig.tight_layout()
# Out:
# Loaded data from ../agents/Acrobot-v1/ppo.pkl.
# Loaded data from ../agents/Acrobot-v1/ppo0.001.pkl.
# Loaded data from ../agents/Acrobot-v1/ppo0.0001.pkl.
# Acrobot-v1 -499.99997
# Loaded data from ../agents/Pendulum-v1/ppo.pkl.
# Loaded data from ../agents/Pendulum-v1/ppo0.001.pkl.
# Loaded data from ../agents/Pendulum-v1/ppo0.0001.pkl.
# Pendulum-v1 -1133.313
# Loaded data from ../agents/CartPole-v1/ppo.pkl.
# Loaded data from ../agents/CartPole-v1/ppo0.001.pkl.
# Loaded data from ../agents/CartPole-v1/ppo0.0001.pkl.
# CartPole-v1 157.71951
# Loaded data from ../agents/MountainCar-v0/ppo.pkl.
# Loaded data from ../agents/MountainCar-v0/ppo0.001.pkl.
# Loaded data from ../agents/MountainCar-v0/ppo0.0001.pkl.
# MountainCar-v0 -200.0
# Loaded data from ../agents/MountainCarContinuous-v0/ppo.pkl.
# Loaded data from ../agents/MountainCarContinuous-v0/ppo0.001.pkl.
# Loaded data from ../agents/MountainCarContinuous-v0/ppo0.0001.pkl.
# MountainCarContinuous-v0 -0.002901021
# ...

# %%
fig.savefig("../docs/lcurves.png", dpi=300)
